# %% [markdown]
# ## 📋 Bugünün Öğrenme Hedefleri
#
# <div style="background-color: #f0f7ff; padding: 20px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#
# ### ✅ Bu dersin sonunda şunları yapabileceksiniz:
#
# - 🔑 **Dictionary (Sözlük)**: Key-value pairing ile verileri organize etme
# - 🎨 **Set (Küme)**: Benzersiz elemanlarla çalışma ve matematiksel işlemler
# - 🔒 **Tuple (Demet)**: Değiştirilemez veri yapıları oluşturma
# - ✅ **Boolean**: Mantıksal işlemler ve koşullu programlama
#
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 25px; border-radius: 15px; color: white; margin: 25px 0; box-shadow: 0 10px 25px rgba(0,0,0,0.1);">
#     <h2 style="color: white; margin-top: 0; text-align: center;">🔥 HAZIR MISINIZ? HADI BAŞLAYALIM! 🔥</h2>
# </div>
#
# ---

# %% [markdown]
# # 📖 BÖLÜM 1: DICTIONARY (SÖZLÜK)
# ## 🔑 Key-Value Pairing Dünyasına Hoş Geldiniz!
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">💡 Dictionary Nedir?</h3>
#     <p style="font-size: 15px;"><strong>Dictionary</strong>, Python'da <strong>anahtar-değer (key-value)</strong> çiftleri ile veri saklayan süper güçlü bir veri yapısıdır!</p>
# </div>

# %% [markdown]
# ## 🤔 List vs Dictionary: Hangisini Kullanmalıyım?
#
# ### 📊 Karşılaştırma:
#
# | Özellik | 📋 List | 🔑 Dictionary |
# |---------|---------|---------------|
# | **Erişim** | Index (0, 1, 2...) | Key (isim, kod...) |
# | **Hız** | Yavaş (arama gerekir) | ⚡ Çok Hızlı! |
# | **Kullanım** | Sıralı veriler | İlişkili veriler |
# | **Örnek** | `[100, 150]` | `{"banana": 100}` |
#
# <div style="background-color: #fff3cd; padding: 15px; border-left: 5px solid #ffc107; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Önemli:</strong> Dictionary'ler gerçek hayatta <strong>telefon rehberi</strong> gibidir! İsim (key) ile telefon numarasına (value) ulaşırsınız.
# </div>

# %% [markdown]
# ## 🔬 Pratik Örnek: List ile Başlayalım
#
# Diyelim ki meyvelerin kalorilerini saklamak istiyoruz. İlk olarak **list** kullanalım:

# %%
# 📋 List kullanarak meyve ve kalori verilerini saklama
fruit_list = ["banana", "apple"]
calorie_list = [100, 150]

print("🍌 Meyveler:", fruit_list)
print("🔥 Kaloriler:", calorie_list)
# Out:
# 🍌 Meyveler: ['banana', 'apple']
# 🔥 Kaloriler: [100, 150]

# %% [markdown]
# ### 🔍 List ile Elemanlara Erişim
#
# Index kullanarak elemanlara ulaşalım:

# %%
# Index 0'daki meyve
fruit_list[0]
# Out:
# 'banana'

# %%
# Index 0'daki kalori değeri
calorie_list[0]
# Out:
# 100

# %% [markdown]
# <div style="background-color: #ffebee; padding: 15px; border-left: 5px solid #f44336; border-radius: 5px; margin: 15px 0;">
#     <strong>❌ Problem:</strong> İki ayrı liste kullanmak karmaşık! Banana'nın kalorisi 100 mü yoksa 150 mi? Sürekli index eşleştirmesi yapmamız gerekiyor. 😓
# </div>

# %% [markdown]
# ## 🎉 Çözüm: DICTIONARY ile Tanışın!
#
# <div style="background-color: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; border-radius: 5px; margin: 15px 0;">
#     <h3 style="color: #2e7d32; margin-top: 0;">✅ Dictionary ile Her Şey Daha Kolay!</h3>
#     <p>Artık <strong>meyve ismi</strong> (key) ile direkt <strong>kalori değerine</strong> (value) ulaşabiliriz! 🚀</p>
# </div>

# %%
# 🔑 Dictionary oluşturma - Key:Value mantığı
fitness_dictionary = {"banana": 100, "apple": 150}

print("📖 Fitness Dictionary:", fitness_dictionary)
print("📊 Veri Tipi:", type(fitness_dictionary))
# Out:
# 📖 Fitness Dictionary: {'banana': 100, 'apple': 150}
# 📊 Veri Tipi: <class 'dict'>

# %% [markdown]
# ### ⚡ Süper Hızlı Erişim!
#
# Dictionary'de **key** kullanarak değere ulaşmak çok kolay:

# %%
# 🍌 Banana'nın kalorisi?
fitness_dictionary["banana"]
# Out:
# 100

# %%
# 🍎 Apple'ın kalorisi?
fitness_dictionary["apple"]
# Out:
# 150

# %% [markdown]
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 20px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">💪 Pro Tip!</h3>
#     <p style="font-size: 15px;">Dictionary'ler <strong>hash table</strong> kullandığı için erişim hızı <strong>O(1)</strong> - yani süper hızlı! ⚡</p>
# </div>

# %% [markdown]
# ## 📝 Flashcard #1: Dictionary Temelleri
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Soru:** Dictionary'nin syntax'ı nedir?
#
# **💡 Cevap:** `{key1: value1, key2: value2}`
#
# **🔑 Önemli:**
# - Süslü parantez `{}` kullanılır
# - Key ve Value iki nokta `:` ile ayrılır
# - Elemanlar virgül `,` ile ayrılır
#
# **✅ Örnek:** `{"isim": "Ahmet", "yaş": 25}`
#
# </div>

# %% [markdown]
# ---
#
# # 🛠️ BÖLÜM 2: DICTIONARY İŞLEMLERİ
# ## 🔧 Methodlar ve Manipülasyon Teknikleri
#
# <div style="background: linear-gradient(135deg, #FA8BFF 0%, #2BD2FF 90%, #2BFF88 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">⚡ Bu Bölümde Neler Öğreneceğiz?</h3>
#     <ul style="font-size: 15px;">
#         <li>🔑 <strong>keys()</strong> - Tüm anahtarları görüntüleme</li>
#         <li>💎 <strong>values()</strong> - Tüm değerleri görüntüleme</li>
#         <li>✏️ <strong>Güncelleme</strong> - Mevcut değerleri değiştirme</li>
#         <li>➕ <strong>Ekleme</strong> - Yeni key-value çiftleri ekleme</li>
#         <li>🔍 <strong>get()</strong> - Güvenli erişim metodu</li>
#     </ul>
# </div>

# %% [markdown]
# ## 🔑 keys() Metodu - Tüm Anahtarları Göster
#
# Dictionary'deki **tüm key'leri** görmek için `keys()` metodunu kullanırız:

# %%
# Önce dictionary'mizi tekrar oluşturalım
fitness_dictionary = {"banana": 100, "apple": 150}

# 🔑 Tüm key'leri görüntüle
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %% [markdown]
# ### 💎 values() Metodu - Tüm Değerleri Göster
#
# Dictionary'deki **tüm value'ları** görmek için `values()` metodunu kullanırız:

# %%
# 💎 Tüm value'ları görüntüle
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %% [markdown]
# ### 🔬 Veri Tipi İncelemesi
#
# `values()` metodu özel bir veri tipi döndürür:

# %%
# 🔍 values() metodunun tipini kontrol et
type(fitness_dictionary.values())
# Out:
# dict_values

# %% [markdown]
# <div style="background-color: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#     <strong>💡 İpucu:</strong> <code>dict_values</code> tipini <strong>list</strong>'e çevirmek isterseniz <code>list()</code> fonksiyonunu kullanın!
# </div>

# %%
# 🔄 dict_values'ı list'e çevirme
list(fitness_dictionary.values())
# Out:
# [100, 150]

# %% [markdown]
# ---
#
# ## ✏️ Dictionary Güncelleme - Var Olan Değerleri Değiştirme
#
# Dictionary'de **mevcut bir key'in value'sunu** değiştirmek çok kolay!

# %%
# 📊 Mevcut dictionary'yi göster
print("🔸 Önce:", fitness_dictionary)

# ✏️ Banana'nın kalorisini 100'den 200'e güncelle
fitness_dictionary["banana"] = 200

# 🔸 Güncellenmiş hali
print("🔹 Sonra:", fitness_dictionary)
# Out:
# 🔸 Önce: {'banana': 100, 'apple': 150}
# 🔹 Sonra: {'banana': 200, 'apple': 150}

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 20px; border-radius: 10px; color: #5d4037; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🎯 Nasıl Çalışır?</h3>
#     <p style="font-size: 15px;"><code>dictionary[key] = yeni_değer</code></p>
#     <p>Eğer <strong>key varsa</strong> → değeri günceller ✅</p>
#     <p>Eğer <strong>key yoksa</strong> → yeni key-value çifti ekler ➕</p>
# </div>

# %% [markdown]
# ## ➕ Yeni Eleman Ekleme
#
# Dictionary'ye **yeni bir key-value çifti** eklemek için aynı syntax'ı kullanırız:

# %%
# ➕ Yeni bir meyve ekleyelim: Melon
fitness_dictionary["melon"] = 300

# 📊 Güncel dictionary
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
# 🍎 Apple'ın kalorisi ne?
fitness_dictionary["apple"]
# Out:
# 150

# %% [markdown]
# ---
#
# ## 🔍 get() Metodu - Güvenli Erişim
#
# <div style="background-color: #ffebee; padding: 20px; border-left: 5px solid #f44336; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Problem:</strong> Olmayan bir key'e erişmeye çalışırsak <strong>KeyError</strong> alırız! 💥
# </div>
#
# ### 🛡️ Çözüm: get() Metodu
#
# `get()` metodu, key yoksa hata vermek yerine **varsayılan bir değer** döndürür:

# %%
# 🔍 get() metodunun yardımını alalım
help(fitness_dictionary.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %% [markdown]
# ### 🧪 get() Metodunu Test Edelim

# %%
# ❌ Olmayan bir key: "appl" (typo!)
# Eğer key yoksa 0 döndür
result = fitness_dictionary.get("appl", 0)
print(f"🔍 Sonuç: {result}")
print("✅ Hata almadık! get() sayesinde güvende olduk.")
# Out:
# 🔍 Sonuç: 0
# ✅ Hata almadık! get() sayesinde güvende olduk.

# %%
# 📊 Mevcut dictionary'yi kontrol edelim
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %% [markdown]
# <div style="background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 20px; border-radius: 10px; color: #1a237e; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">💪 Pro Tip: get() vs [] Erişimi</h3>
#     <table style="width: 100%; border-collapse: collapse;">
#         <tr>
#             <th style="padding: 10px; text-align: left; border-bottom: 2px solid #1a237e;">Metod</th>
#             <th style="padding: 10px; text-align: left; border-bottom: 2px solid #1a237e;">Key Varsa</th>
#             <th style="padding: 10px; text-align: left; border-bottom: 2px solid #1a237e;">Key Yoksa</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><code>dict[key]</code></td>
#             <td style="padding: 10px;">✅ Value döner</td>
#             <td style="padding: 10px;">❌ KeyError!</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><code>dict.get(key, default)</code></td>
#             <td style="padding: 10px;">✅ Value döner</td>
#             <td style="padding: 10px;">✅ Default döner</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ## 📝 Flashcard #2: Dictionary İşlemleri
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Dictionary'de tüm key'leri nasıl görürüz?
# **A1:** `dictionary.keys()` 🔑
#
# ---
#
# **Q2:** Dictionary'de tüm value'ları nasıl görürüz?
# **A2:** `dictionary.values()` 💎
#
# ---
#
# **Q3:** Var olan bir değeri nasıl güncelleriz?
# **A3:** `dictionary[key] = yeni_değer` ✏️
#
# ---
#
# **Q4:** Yeni eleman nasıl ekleriz?
# **A4:** `dictionary[yeni_key] = yeni_değer` ➕
#
# ---
#
# **Q5:** Güvenli erişim için hangi metodu kullanırız?
# **A5:** `dictionary.get(key, default_değer)` 🛡️
#
# </div>

# %% [markdown]
# ---
#
# # 🚀 BÖLÜM 3: DICTIONARY İLERİ SEVİYE
# ## 💎 Farklı Veri Tipleri & Nested Dictionaries
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="color: white; margin-top: 0;">🎯 İleri Seviye Yetenekler</h3>
#     <p style="font-size: 15px;">Dictionary'ler <strong>herhangi bir veri tipi</strong> saklayabilir! Sayılar, stringler, listeler, hatta başka dictionary'ler bile! 🤯</p>
# </div>

# %% [markdown]
# ## 🔢 Key Olarak Sayı Kullanımı
#
# Dictionary'lerde **key** sadece string olmak zorunda değil! Sayılar da kullanılabilir:

# %%
# 🔢 Sayısal key'ler kullanalım
my_dictionary = {100: "a", 200: "b", 300: "c"}

print("📖 Dictionary:", my_dictionary)
print("📊 Tip:", type(my_dictionary))
# Out:
# 📖 Dictionary: {100: 'a', 200: 'b', 300: 'c'}
# 📊 Tip: <class 'dict'>

# %% [markdown]
# ### 🔍 Sayısal Key ile Erişim

# %%
# Key 100'e karşılık gelen değer?
my_dictionary[100]
# Out:
# 'a'

# %%
# Key 200'e karşılık gelen değer?
my_dictionary[200]
# Out:
# 'b'

# %% [markdown]
# <div style="background-color: #fff3cd; padding: 15px; border-left: 5px solid #ffc107; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Dikkat:</strong> <code>my_dictionary[100]</code> ile <code>my_list[100]</code> farklıdır!
#     <ul>
#         <li>📋 List: 100. <strong>index</strong>'teki eleman</li>
#         <li>📖 Dictionary: <strong>Key</strong>'i 100 olan eleman</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🎨 Klasik String Key Dictionary

# %%
# 📝 String key'ler - en yaygın kullanım
my_dictionary = {"key1": "value1", "key2": "value2", "key3": "value3"}

# İlk key'in değeri
my_dictionary["key1"]
# Out:
# 'value1'

# %% [markdown]
# ---
#
# ## 🌈 Mixed Dictionary - Karışık Veri Tipleri
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">💪 Süper Güç Açıldı!</h3>
#     <p style="font-size: 15px;">Dictionary'lerde <strong>value</strong> olarak <strong>herhangi bir veri tipi</strong> kullanılabilir!</p>
#     <ul style="font-size: 14px;">
#         <li>✅ Integer (tam sayılar)</li>
#         <li>✅ Float (ondalıklı sayılar)</li>
#         <li>✅ String (metinler)</li>
#         <li>✅ List (listeler)</li>
#         <li>✅ Dictionary (iç içe sözlükler)</li>
#         <li>✅ Ve daha fazlası!</li>
#     </ul>
# </div>

# %%
# 🌈 Karışık veri tiplerinde dictionary
my_mixed_dictionary = {
    "key1": 100,              # Integer
    "key2": 3.14,             # Float
    "key3": [10, 20, 30]      # List
}

print("📖 Mixed Dictionary:")
print(my_mixed_dictionary)
# Out:
# 📖 Mixed Dictionary:
# {'key1': 100, 'key2': 3.14, 'key3': [10, 20, 30]}

# %% [markdown]
# ### 🎯 List Value'ya Erişim
#
# Dictionary içindeki **list** elemanına nasıl erişeriz?

# %%
# 📋 Önce list'i alalım
print("🔹 Tüm list:", my_mixed_dictionary["key3"])

# 🎯 List'in ikinci elemanına (index 1) erişelim
print("🔹 İkinci eleman:", my_mixed_dictionary["key3"][1])
# Out:
# 🔹 Tüm list: [10, 20, 30]
# 🔹 İkinci eleman: 20

# %% [markdown]
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 20px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">💡 Erişim Mantığı</h3>
#     <p style="font-size: 15px;"><code>my_mixed_dictionary["key3"][1]</code></p>
#     <ol style="font-size: 14px;">
#         <li><code>my_mixed_dictionary["key3"]</code> → <code>[10, 20, 30]</code> listesini döndür</li>
#         <li><code>[10, 20, 30][1]</code> → İkinci elemanı (20) döndür</li>
#     </ol>
#     <p style="font-size: 14px;"><strong>Sonuç:</strong> 20 ✅</p>
# </div>

# %% [markdown]
# ---
#
# ## 🏗️ NESTED DICTIONARY - İç İçe Sözlükler
#
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; color: #4a0e0e; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="margin-top: 0;">🚀 Gerçek Dünya Senaryosu!</h3>
#     <p style="font-size: 15px;">Dictionary içinde dictionary! Bu yapı <strong>JSON veriler</strong> ve <strong>API'ler</strong> ile çalışırken sürekli kullanılır! 🌐</p>
# </div>

# %%
# 🏗️ Karmaşık nested dictionary
last_dictionary = {
    "k1": 10,                          # Integer value
    "k2": [10, 20, 30, 40, 50],       # List value
    "k3": "string",                    # String value
    "k4": {"a": 100, "b": 200}        # Dictionary value! 🤯
}

print("📖 Nested Dictionary:")
print(last_dictionary)
# Out:
# 📖 Nested Dictionary:
# {'k1': 10, 'k2': [10, 20, 30, 40, 50], 'k3': 'string', 'k4': {'a': 100, 'b': 200}}

# %% [markdown]
# ### 🎯 Örnek 1: List İçinden Eleman Çekme

# %%
# 📋 k2 list'inin 3. elemanını (index 2) alalım
print("🔹 k2'nin tüm değeri:", last_dictionary["k2"])
print("🔹 k2'nin 3. elemanı (index 2):", last_dictionary["k2"][2])
# Out:
# 🔹 k2'nin tüm değeri: [10, 20, 30, 40, 50]
# 🔹 k2'nin 3. elemanı (index 2): 30

# %% [markdown]
# ### 🎯 Örnek 2: Nested Dictionary'den Değer Çekme
#
# Bu en ilginç kısım! İç içe dictionary'den değer almak:

# %%
# 📖 İç dictionary'ye erişim
print("🔹 k4'ün tüm değeri:", last_dictionary["k4"])
print("🔹 k4 içindeki 'b' değeri:", last_dictionary["k4"]["b"])
# Out:
# 🔹 k4'ün tüm değeri: {'a': 100, 'b': 200}
# 🔹 k4 içindeki 'b' değeri: 200

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 20px; border-radius: 10px; color: #5d4037; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🔥 Nested Dictionary Erişim Adımları</h3>
#     <p style="font-size: 15px;"><code>last_dictionary["k4"]["b"]</code></p>
#     <div style="background: white; padding: 15px; border-radius: 5px; margin: 10px 0;">
#         <p style="margin: 5px 0; color: #5d4037;"><strong>Adım 1:</strong> <code>last_dictionary["k4"]</code> → <code>{"a": 100, "b": 200}</code></p>
#         <p style="margin: 5px 0; color: #5d4037;"><strong>Adım 2:</strong> <code>{"a": 100, "b": 200}["b"]</code> → <code>200</code></p>
#         <p style="margin: 5px 0; color: #d84315;"><strong>✅ Sonuç:</strong> <code>200</code></p>
#     </div>
# </div>

# %% [markdown]
# ## 📝 Flashcard #3: İleri Seviye Dictionary
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Dictionary'de key olarak hangi veri tipleri kullanılabilir?
# **A1:** String, Integer, Float, Tuple (immutable tipler) 🔑
#
# ---
#
# **Q2:** Dictionary'de value olarak hangi veri tipleri kullanılabilir?
# **A2:** **HER TÜRLÜ** veri tipi! Integer, Float, String, List, Dict, vs. 🌈
#
# ---
#
# **Q3:** `my_dict["key"][2]` ne anlama gelir?
# **A3:** `my_dict["key"]` value'sunu al (muhtemelen list), sonra onun 3. elemanını (index 2) al 🎯
#
# ---
#
# **Q4:** Nested dictionary'den değer almak için kaç köşeli parantez kullanırız?
# **A4:** Her seviye için bir tane: `dict["key1"]["key2"]` 📦
#
# ---
#
# **Q5:** Gerçek dünyada nested dictionary nerede kullanılır?
# **A5:** JSON API'ler, config dosyalar, kompleks veri yapıları 🌐
#
# </div>

# %% [markdown]
# ---
# ---
#
# # 🎨 BÖLÜM 4: SET (KÜME)
# ## ✨ Benzersiz Elemanlar ve Matematiksel İşlemler
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="color: white; margin-top: 0;">🎯 Set Nedir?</h3>
#     <p style="font-size: 15px;"><strong>Set</strong>, matematikteki <strong>küme</strong> kavramının Python'daki karşılığıdır. Her eleman <strong>sadece bir kez</strong> bulunur ve elemanlar <strong>sırasızdır</strong>! 🌟</p>
# </div>

# %% [markdown]
# ## 🔬 Problem: List'te Tekrarlı Elemanlar
#
# Diyelim ki bir listede tekrarlı elemanlar var:

# %%
# 📋 Tekrarlı elemanlar içeren liste
myList = [10, 20, 30, 10, 20, 40, 10, 20, 40]

print("📋 Liste:", myList)
print("📏 Eleman sayısı:", len(myList))
# Out:
# 📋 Liste: [10, 20, 30, 10, 20, 40, 10, 20, 40]
# 📏 Eleman sayısı: 9

# %% [markdown]
# <div style="background-color: #ffebee; padding: 15px; border-left: 5px solid #f44336; border-radius: 5px; margin: 15px 0;">
#     <strong>❌ Problem:</strong> Liste 9 eleman gösteriyor ama aslında sadece <strong>4 benzersiz</strong> değer var (10, 20, 30, 40)! 😕
# </div>

# %% [markdown]
# ## ✨ Çözüm: Set ile Benzersiz Elemanlar
#
# <div style="background-color: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; border-radius: 5px; margin: 15px 0;">
#     <h3 style="color: #2e7d32; margin-top: 0;">✅ Set Büyülü Gücü!</h3>
#     <p><strong>set()</strong> fonksiyonu ile list'i set'e çevirdiğimizde, tüm tekrarlar <strong>otomatik olarak</strong> temizlenir! 🎉</p>
# </div>

# %%
# 🎨 List'i Set'e çevirme
mySet = set(myList)

print("🎨 Set:", mySet)
print("📏 Benzersiz eleman sayısı:", len(mySet))
# Out:
# 🎨 Set: {40, 10, 20, 30}
# 📏 Benzersiz eleman sayısı: 4

# %% [markdown]
# <div style="background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 20px; border-radius: 10px; color: #1a237e; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🎉 Harika! Ne Oldu?</h3>
#     <ul style="font-size: 14px;">
#         <li>📋 List: <strong>9 eleman</strong> (tekrarlılar dahil)</li>
#         <li>🎨 Set: <strong>4 eleman</strong> (sadece benzersizler)</li>
#         <li>✨ Tekrarlar otomatik silindi: {10, 20, 30, 40}</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🛠️ Direkt Set Oluşturma
#
# List'ten dönüştürmek yerine **direkt set oluşturabiliriz**:

# %%
# 🎨 Süslü parantez {} ile set oluşturma
mySet = {10, 20, 30, 10, 20, 40, 10, 20, 40}

print("🎨 Set:", mySet)
print("📊 Tip:", type(mySet))
# Out:
# 🎨 Set: {40, 10, 20, 30}
# 📊 Tip: <class 'set'>

# %% [markdown]
# <div style="background-color: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#     <strong>💡 İpucu:</strong> Set oluştururken tekrarlı elemanlar yazsanız bile, Python otomatik olarak temizler! 🧹
# </div>

# %% [markdown]
# ---
#
# ## ➕ Set'e Eleman Ekleme - add() Metodu

# %%
# 🎨 Mevcut set'imiz
mySet = {10, 20, 30, 40}
print("🔹 Başlangıç:", mySet)
# Out:
# 🔹 Başlangıç: {40, 10, 20, 30}

# %% [markdown]
# ### 🧪 Test 1: Var Olan Elemanı Ekleme

# %%
# ➕ Zaten var olan 10'u eklemeye çalışalım
mySet.add(10)
print("🔹 10 ekledikten sonra:", mySet)
# Out:
# 🔹 10 ekledikten sonra: {40, 10, 20, 30}

# %% [markdown]
# <div style="background-color: #fff3cd; padding: 15px; border-left: 5px solid #ffc107; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Dikkat:</strong> Zaten var olan bir elemanı eklemeye çalışırsak, <strong>değişiklik olmaz</strong>! Set'ler tekrar kabul etmez. ✋
# </div>

# %% [markdown]
# ### 🧪 Test 2: Yeni Eleman Ekleme

# %%
# ➕ Yeni eleman 50'yi ekleyelim
mySet.add(50)
print("🔹 50 ekledikten sonra:", mySet)
# Out:
# 🔹 50 ekledikten sonra: {40, 10, 50, 20, 30}

# %% [markdown]
# <div style="background-color: #e8f5e9; padding: 15px; border-left: 5px solid #4caf50; border-radius: 5px; margin: 15px 0;">
#     <strong>✅ Başarılı:</strong> Yeni eleman 50 set'e başarıyla eklendi! 🎉
# </div>

# %% [markdown]
# ---
#
# ## 📝 Flashcard #4: Set Temelleri
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Set'in en önemli özelliği nedir?
# **A1:** Her eleman **sadece bir kez** bulunur (unique/benzersiz) ✨
#
# ---
#
# **Q2:** Set'ler sıralı mıdır?
# **A2:** **Hayır**, set'ler sırasızdır (unordered). Index kullanılamaz! 🔀
#
# ---
#
# **Q3:** List'i set'e nasıl çeviririz?
# **A3:** `set(myList)` fonksiyonunu kullanarak 🔄
#
# ---
#
# **Q4:** Set nasıl oluşturulur?
# **A4:** İki yol: `{1, 2, 3}` veya `set([1, 2, 3])` 🛠️
#
# ---
#
# **Q5:** Set'e eleman eklemek için hangi metod kullanılır?
# **A5:** `mySet.add(eleman)` metodu ➕
#
# ---
#
# **Q6:** Zaten var olan bir elemanı tekrar eklersek ne olur?
# **A6:** Hiçbir şey! Set değişmez, tekrar kabul etmez 🚫
#
# </div>

# %% [markdown]
# ## 📊 List vs Set Karşılaştırması
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">🤔 Hangisini Ne Zaman Kullanmalıyız?</h3>
#     <table style="width: 100%; border-collapse: collapse; color: white;">
#         <tr style="border-bottom: 2px solid white;">
#             <th style="padding: 10px; text-align: left;">Özellik</th>
#             <th style="padding: 10px; text-align: left;">📋 List</th>
#             <th style="padding: 10px; text-align: left;">🎨 Set</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Sıralı</strong></td>
#             <td style="padding: 10px;">✅ Evet</td>
#             <td style="padding: 10px;">❌ Hayır</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Index</strong></td>
#             <td style="padding: 10px;">✅ Kullanılır</td>
#             <td style="padding: 10px;">❌ Kullanılamaz</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Tekrar</strong></td>
#             <td style="padding: 10px;">✅ İzin verir</td>
#             <td style="padding: 10px;">❌ İzin vermez</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Değiştirilebilir</strong></td>
#             <td style="padding: 10px;">✅ Evet</td>
#             <td style="padding: 10px;">✅ Evet</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Syntax</strong></td>
#             <td style="padding: 10px;">[1, 2, 3]</td>
#             <td style="padding: 10px;">{1, 2, 3}</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ---
#
# # 🔢 BÖLÜM 5: SET MATEMATİKSEL İŞLEMLERİ
# ## 🎓 Union & Intersection - Küme Teorisi
#
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; color: #4a0e0e; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="margin-top: 0;">🎯 Matematik + Python = Güç! 💪</h3>
#     <p style="font-size: 15px;">Set'ler matematikteki <strong>küme işlemlerini</strong> Python'da yapmamızı sağlar! Birleşim, kesişim ve daha fazlası! 📐</p>
# </div>

# %% [markdown]
# ## 🎨 İki Set Oluşturalım

# %%
# 🎨 İki farklı set oluşturalım
mySet = {10, 20, 30, 40, 50}
mySet2 = {30, 40, 50, 60, 70}

print("🔹 Set 1:", mySet)
print("🔹 Set 2:", mySet2)
# Out:
# 🔹 Set 1: {50, 20, 40, 10, 30}
# 🔹 Set 2: {50, 70, 40, 60, 30}

# %% [markdown]
# <div style="background-color: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#     <strong>💡 Gözlem:</strong> İki set'te de <strong>ortak elemanlar</strong> var: 30, 40, 50 🤝
# </div>

# %% [markdown]
# ---
#
# ## 🤝 UNION (BİRLEŞİM) - Tüm Elemanları Birleştir
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">📚 Union Nedir?</h3>
#     <p style="font-size: 15px;"><strong>union()</strong> metodu iki set'teki <strong>tüm elemanları</strong> birleştirir. Tekrarlar otomatik temizlenir! 🎉</p>
#     <p style="font-size: 14px; margin: 5px 0;">📐 Matematiksel sembol: A ∪ B</p>
# </div>

# %%
# 🤝 İki set'i birleştir (union)
union_result = mySet.union(mySet2)

print("🔹 Set 1:", mySet)
print("🔹 Set 2:", mySet2)
print("✨ Union (Birleşim):", union_result)
# Out:
# 🔹 Set 1: {50, 20, 40, 10, 30}
# 🔹 Set 2: {50, 70, 40, 60, 30}
# ✨ Union (Birleşim): {70, 40, 10, 50, 20, 60, 30}

# %% [markdown]
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 20px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🎉 Sonuç Analizi</h3>
#     <ul style="font-size: 14px;">
#         <li>📊 Set 1: {10, 20, 30, 40, 50}</li>
#         <li>📊 Set 2: {30, 40, 50, 60, 70}</li>
#         <li>✨ <strong>Union:</strong> {10, 20, 30, 40, 50, 60, 70}</li>
#     </ul>
#     <p style="font-size: 14px; margin-top: 15px;"><strong>🔥 Her iki set'teki TÜM elemanlar, tekrarsız!</strong></p>
# </div>

# %% [markdown]
# ---
#
# ## 🎯 INTERSECTION (KESİŞİM) - Ortak Elemanlar
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">📚 Intersection Nedir?</h3>
#     <p style="font-size: 15px;"><strong>intersection()</strong> metodu iki set'te de <strong>ortak olan</strong> elemanları döndürür! 🤝</p>
#     <p style="font-size: 14px; margin: 5px 0;">📐 Matematiksel sembol: A ∩ B</p>
# </div>

# %%
# 🎯 İki set'in kesişimini bul (intersection)
intersection_result = mySet.intersection(mySet2)

print("🔹 Set 1:", mySet)
print("🔹 Set 2:", mySet2)
print("🎯 Intersection (Kesişim):", intersection_result)
# Out:
# 🔹 Set 1: {50, 20, 40, 10, 30}
# 🔹 Set 2: {50, 70, 40, 60, 30}
# 🎯 Intersection (Kesişim): {40, 50, 30}

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 20px; border-radius: 10px; color: #5d4037; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🎯 Sonuç Analizi</h3>
#     <ul style="font-size: 14px;">
#         <li>📊 Set 1: {10, 20, <strong>30, 40, 50</strong>}</li>
#         <li>📊 Set 2: {<strong>30, 40, 50</strong>, 60, 70}</li>
#         <li>🎯 <strong>Intersection:</strong> {30, 40, 50}</li>
#     </ul>
#     <p style="font-size: 14px; margin-top: 15px;"><strong>🔥 Sadece HER İKİSİNDE de bulunan elemanlar!</strong></p>
# </div>

# %% [markdown]
# ---
#
# ## 🌍 GERÇEK HAYAT ÖRNEĞİ: Ülke Analitiği
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">📊 Senaryo: Ülke Verisi Analizi</h3>
#     <p style="font-size: 15px;">Bir sistemde ülke kodları kayıtlı. Kaç <strong>benzersiz ülke</strong> var? 🌐</p>
# </div>

# %%
# 🌍 Kullanıcıların ülke kodları (tekrarlı)
countryList = ["de", "fr", "tr", "fr", "tr", "tr", "de", "nl", "de", "tr"]

print("📋 Ülke Listesi (tekrarlı):", countryList)
print("📏 Toplam kayıt:", len(countryList))
# Out:
# 📋 Ülke Listesi (tekrarlı): ['de', 'fr', 'tr', 'fr', 'tr', 'tr', 'de', 'nl', 'de', 'tr']
# 📏 Toplam kayıt: 10

# %% [markdown]
# ### 🎯 Soru: Kaç Benzersiz Ülke Var?
#
# Set kullanarak hızlıca bulalım:

# %%
# ✨ Set ile benzersiz ülkeleri bulma
unique_countries = set(countryList)

print("🎨 Benzersiz Ülkeler:", unique_countries)
print("🔥 Benzersiz ülke sayısı:", len(unique_countries))
# Out:
# 🎨 Benzersiz Ülkeler: {'tr', 'de', 'fr', 'nl'}
# 🔥 Benzersiz ülke sayısı: 4

# %% [markdown]
# <div style="background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 20px; border-radius: 10px; color: #1a237e; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">📊 Analiz Sonuçları</h3>
#     <ul style="font-size: 14px;">
#         <li>📋 Toplam kayıt: <strong>10</strong></li>
#         <li>🎨 Benzersiz ülke: <strong>4</strong> (de, fr, tr, nl)</li>
#         <li>♻️ Tekrar eden kayıt: <strong>6</strong></li>
#     </ul>
#     <p style="font-size: 14px; margin-top: 15px;"><strong>💡 Tek satır kod ile veri temizliği!</strong> 🚀</p>
# </div>

# %% [markdown]
# ---
#
# ## ⚠️ DİKKAT: Empty Set vs Empty Dict
#
# <div style="background-color: #ffebee; padding: 20px; border-left: 5px solid #f44336; border-radius: 5px; margin: 15px 0;">
#     <h3 style="color: #c62828; margin-top: 0;">❌ Sık Yapılan Hata!</h3>
#     <p><strong>Boş süslü parantez</strong> <code>{}</code> kullanırsanız, Python bunu <strong>dictionary</strong> olarak algılar! 😱</p>
# </div>

# %%
# ❌ Yanlış! Bu bir dictionary oluşturur
emptySet = {}
print("❌ Tip:", type(emptySet))  # dict!
# Out:
# ❌ Tip: <class 'dict'>

# %% [markdown]
# ### ✅ Doğru Yol: set() Fonksiyonu

# %%
# ✅ Doğru! Boş set oluşturma
emptySet = set()
print("✅ Tip:", type(emptySet))  # set!
print("📏 Uzunluk:", len(emptySet))
# Out:
# ✅ Tip: <class 'set'>
# 📏 Uzunluk: 0

# %% [markdown]
# ### 🧪 Boş Set'e Eleman Ekleyelim

# %%
# ➕ Boş set'e elemanlar ekleyelim
emptySet = set()
emptySet.add(10)
emptySet.add(10)  # Tekrar, eklenmez
emptySet.add(10)  # Tekrar, eklenmez
emptySet.add(20)
emptySet.add(30)

print("🎨 Set:", emptySet)
print("📏 Eleman sayısı:", len(emptySet))
# Out:
# 🎨 Set: {10, 20, 30}
# 📏 Eleman sayısı: 3

# %% [markdown]
# ---
#
# ## 🔄 Bonus: List vs Set vs Dict Oluşturma
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">📚 Boş Veri Yapıları Nasıl Oluşturulur?</h3>
#     <table style="width: 100%; border-collapse: collapse; color: white;">
#         <tr style="border-bottom: 2px solid white;">
#             <th style="padding: 10px; text-align: left;">Veri Yapısı</th>
#             <th style="padding: 10px; text-align: left;">Syntax</th>
#             <th style="padding: 10px; text-align: left;">Alternatif</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;">📋 <strong>List</strong></td>
#             <td style="padding: 10px;"><code>[]</code></td>
#             <td style="padding: 10px;"><code>list()</code></td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;">🎨 <strong>Set</strong></td>
#             <td style="padding: 10px;"><code>set()</code> ⚠️</td>
#             <td style="padding: 10px;">-</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;">📖 <strong>Dictionary</strong></td>
#             <td style="padding: 10px;"><code>{}</code></td>
#             <td style="padding: 10px;"><code>dict()</code></td>
#         </tr>
#     </table>
# </div>

# %%
# 📚 Tüm veri yapılarını oluşturma
emptyList = list()
emptySet = set()
emptyDictionary = dict()

# Elemanlar ekleyelim
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

emptyDictionary["a"] = 10
emptyDictionary["b"] = 20

print("📋 List:", emptyList)
print("🎨 Set:", emptySet)
print("📖 Dict:", emptyDictionary)
# Out:
# 📋 List: [10, 20, 30]
# 🎨 Set: {10, 20, 30}
# 📖 Dict: {'a': 10, 'b': 20}

# %% [markdown]
# ## 📝 Flashcard #5: Set İşlemleri
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Union işlemi ne yapar?
# **A1:** İki set'teki **tüm elemanları** birleştirir (tekrarsız) 🤝
#
# ---
#
# **Q2:** Intersection işlemi ne yapar?
# **A2:** İki set'te de **ortak olan** elemanları döndürür 🎯
#
# ---
#
# **Q3:** Union'ın matematiksel sembolü nedir?
# **A3:** A ∪ B (U sembolü) ∪
#
# ---
#
# **Q4:** Intersection'ın matematiksel sembolü nedir?
# **A4:** A ∩ B (ters U sembolü) ∩
#
# ---
#
# **Q5:** Boş set nasıl oluşturulur?
# **A5:** `set()` fonksiyonu ile. `{}` kullanılmaz! (o dict oluşturur) ⚠️
#
# ---
#
# **Q6:** Set'ler gerçek hayatta nerede kullanılır?
# **A6:** Benzersiz değer bulma, tekrar silme, üyelik kontrolü 🌍
#
# </div>

# %% [markdown]
# ---
# ---
#
# # 🔒 BÖLÜM 6: TUPLE (DEMET)
# ## 🛡️ Değiştirilemez Veri Yapıları - Immutability
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="color: white; margin-top: 0;">🎯 Tuple Nedir?</h3>
#     <p style="font-size: 15px;"><strong>Tuple</strong>, List'e çok benzer ama <strong>DEĞİŞTİRİLEMEZ</strong> (immutable)! Bir kez oluşturduktan sonra içeriği değiştirilemez! 🔐</p>
# </div>

# %% [markdown]
# ## 📋 Hatırlayalım: List (Değiştirilebilir)

# %%
# 📋 List oluşturma - değiştirilebilir (mutable)
myList = [10, "a", "b", 3.14]

print("🔹 Başlangıç:", myList)
print("🔹 İlk eleman:", myList[0])
# Out:
# 🔹 Başlangıç: [10, 'a', 'b', 3.14]
# 🔹 İlk eleman: 10

# %% [markdown]
# ### ✏️ List Elemanlarını Değiştirme - Mümkün!

# %%
# ✅ List'te değişiklik yapabiliriz!
myList[0] = 100

print("✅ Değiştirildikten sonra:", myList)
print("🎉 List'ler MUTABLE (değiştirilebilir)!")
# Out:
# ✅ Değiştirildikten sonra: [100, 'a', 'b', 3.14]
# 🎉 List'ler MUTABLE (değiştirilebilir)!

# %% [markdown]
# ---
#
# ## 🔒 Tuple Oluşturma - Değiştirilemez!
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">🛡️ Tuple'ın Süper Gücü: Immutability!</h3>
#     <p style="font-size: 15px;">Tuple elemanları <strong>değiştirilemez</strong>, <strong>silinemez</strong>, <strong>eklenemez</strong>! Güvenli ve hızlı! ⚡</p>
#     <p style="font-size: 14px;">📌 Syntax: <code style="background: rgba(255,255,255,0.2); padding: 3px 8px; border-radius: 3px;">(eleman1, eleman2, ...)</code></p>
# </div>

# %%
# 🔒 Tuple oluşturma - parantez () kullanılır
myTuple = (10, "a", "b", 3.14)

print("🔒 Tuple:", myTuple)
print("📊 Tip:", type(myTuple))
# Out:
# 🔒 Tuple: (10, 'a', 'b', 3.14)
# 📊 Tip: <class 'tuple'>

# %% [markdown]
# ### 🔍 Tuple Elemanlarına Erişim
#
# List gibi **index** kullanarak elemanlara erişebiliriz:

# %%
# 🔍 Index ile erişim
print("🔹 İlk eleman (index 0):", myTuple[0])
print("🔹 İkinci eleman (index 1):", myTuple[1])
# Out:
# 🔹 İlk eleman (index 0): 10
# 🔹 İkinci eleman (index 1): a

# %% [markdown]
# ---
#
# ## ❌ Immutability Testi - Değiştiremezsiniz!
#
# <div style="background-color: #ffebee; padding: 20px; border-left: 5px solid #f44336; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Dikkat:</strong> Tuple elemanlarını değiştirmeye çalışırsanız <strong>TypeError</strong> alırsınız! 💥
# </div>

# %%
# ❌ Tuple'ı değiştirmeye çalışalım - HATA ALACAĞIZ!
# Uncomment yaparsanız hata verecek:
# myTuple[0] = 100  # TypeError: 'tuple' object does not support item assignment

print("❌ Tuple elemanları değiştirilemez!")
print("🔒 Immutability = Değiştirilemezlik")
print("🛡️ Bu tuple'ın güvenlik özelliğidir!")
# Out:
# ❌ Tuple elemanları değiştirilemez!
# 🔒 Immutability = Değiştirilemezlik
# 🛡️ Bu tuple'ın güvenlik özelliğidir!

# %% [markdown]
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 20px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🤔 Neden Tuple Kullanırız?</h3>
#     <ul style="font-size: 14px;">
#         <li>🛡️ <strong>Güvenlik:</strong> Yanlışlıkla değiştirilmesini istemediğiniz veriler</li>
#         <li>⚡ <strong>Performans:</strong> List'ten daha hızlı!</li>
#         <li>🔑 <strong>Dictionary Key:</strong> Tuple dictionary'de key olarak kullanılabilir (list olamaz)</li>
#         <li>🔒 <strong>Sabit Değerler:</strong> Koordinatlar, tarih bilgileri gibi</li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🛠️ Tuple Metodları
#
# Tuple immutable olduğu için çok az metodu vardır:

# %%
# 🔒 Örnek tuple
myTuple = (10, "a", "b", 3.14, "a")
print("🔒 Tuple:", myTuple)
# Out:
# 🔒 Tuple: (10, 'a', 'b', 3.14, 'a')

# %% [markdown]
# ### 🔍 index() - Elemanın İndexini Bul

# %%
# 🔍 "a" elemanının index'ini bul
index_of_a = myTuple.index("a")
print("🔹 'a' elemanının index'i:", index_of_a)
# Out:
# 🔹 'a' elemanının index'i: 1

# %% [markdown]
# <div style="background-color: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#     <strong>💡 Not:</strong> Eğer eleman birden fazla varsa, <code>index()</code> <strong>ilk bulduğunu</strong> döndürür!
# </div>

# %% [markdown]
# ### 🔢 count() - Elemanın Kaç Kez Geçtiğini Say

# %%
# 🔢 "a" elemanı tuple'da kaç kez var?
count_of_a = myTuple.count("a")
print("🔹 'a' elemanı", count_of_a, "kez geçiyor")
# Out:
# 🔹 'a' elemanı 2 kez geçiyor

# %% [markdown]
# ---
#
# ## 🔄 Tuple ↔ List Dönüşümü
#
# Bazen tuple'ı list'e çevirmemiz gerekebilir:

# %%
# 🔒 Tuple'dan başlayalım
resultTuple = (10, 100, 20)
print("🔒 Tuple:", resultTuple)
print("📊 Tip:", type(resultTuple))
# Out:
# 🔒 Tuple: (10, 100, 20)
# 📊 Tip: <class 'tuple'>

# %% [markdown]
# ### 📋 Tuple → List Dönüşümü

# %%
# 🔄 Tuple'ı list'e çevir
resultList = list(resultTuple)

print("📋 List:", resultList)
print("📊 Tip:", type(resultList))
print("✅ Artık değiştirilebilir!")
# Out:
# 📋 List: [10, 100, 20]
# 📊 Tip: <class 'list'>
# ✅ Artık değiştirilebilir!

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 20px; border-radius: 10px; color: #5d4037; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🔄 Ne Zaman Dönüştürürüz?</h3>
#     <ul style="font-size: 14px;">
#         <li>📋 <strong>Tuple → List:</strong> Değişiklik yapmak istediğimizde</li>
#         <li>🔒 <strong>List → Tuple:</strong> Veriyi koruma altına almak istediğimizde</li>
#         <li>🔑 <strong>List → Tuple:</strong> Dictionary key olarak kullanmak için</li>
#     </ul>
# </div>

# %% [markdown]
# ## 📊 List vs Tuple Karşılaştırması
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">🤔 Farkları Anlamak Önemli!</h3>
#     <table style="width: 100%; border-collapse: collapse; color: white;">
#         <tr style="border-bottom: 2px solid white;">
#             <th style="padding: 10px; text-align: left;">Özellik</th>
#             <th style="padding: 10px; text-align: left;">📋 List</th>
#             <th style="padding: 10px; text-align: left;">🔒 Tuple</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Syntax</strong></td>
#             <td style="padding: 10px;"><code>[]</code></td>
#             <td style="padding: 10px;"><code>()</code></td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Değiştirilebilir</strong></td>
#             <td style="padding: 10px;">✅ Evet (Mutable)</td>
#             <td style="padding: 10px;">❌ Hayır (Immutable)</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Hız</strong></td>
#             <td style="padding: 10px;">🐢 Yavaş</td>
#             <td style="padding: 10px;">⚡ Hızlı</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Metodlar</strong></td>
#             <td style="padding: 10px;">Çok (append, remove...)</td>
#             <td style="padding: 10px;">Az (index, count)</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Dict Key</strong></td>
#             <td style="padding: 10px;">❌ Olamaz</td>
#             <td style="padding: 10px;">✅ Olabilir</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Kullanım</strong></td>
#             <td style="padding: 10px;">Dinamik veri</td>
#             <td style="padding: 10px;">Sabit veri</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ## 📝 Flashcard #6: Tuple
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Tuple'ın en önemli özelliği nedir?
# **A1:** **Immutable** (değiştirilemez) olmasıdır 🔒
#
# ---
#
# **Q2:** Tuple syntax'ı nedir?
# **A2:** Parantez kullanılır: `(eleman1, eleman2, ...)` ()
#
# ---
#
# **Q3:** Tuple elemanlarına nasıl erişiriz?
# **A3:** List gibi **index** kullanarak: `myTuple[0]` 🔍
#
# ---
#
# **Q4:** Tuple'ın metodları nelerdir?
# **A4:** Sadece `index()` ve `count()` 🛠️
#
# ---
#
# **Q5:** Tuple'ı list'e nasıl çeviririz?
# **A5:** `list(myTuple)` fonksiyonuyla 🔄
#
# ---
#
# **Q6:** Tuple ne zaman kullanılır?
# **A6:** Değiştirilmemesi gereken sabit veriler için (koordinatlar, tarih, config) 🛡️
#
# ---
#
# **Q7:** List vs Tuple performans?
# **A7:** Tuple daha **hızlıdır** çünkü immutable'dır ⚡
#
# </div>

# %% [markdown]
# ---
# ---
#
# # ✅ BÖLÜM 7: BOOLEAN (MANTIKSAL DEĞİŞKENLER)
# ## 🔴🟢 True & False - Mantıksal Düşünce
#
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; color: #4a0e0e; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#     <h3 style="margin-top: 0;">🎯 Boolean Nedir?</h3>
#     <p style="font-size: 15px;"><strong>Boolean</strong>, sadece iki değer alabilen bir veri tipidir: <strong>True</strong> (Doğru) veya <strong>False</strong> (Yanlış). Programlamanın temeli! 🔥</p>
# </div>

# %% [markdown]
# ## 🔴🟢 Boolean Değerleri

# %%
# ✅ Boolean değerleri
print("✅ True:", True)
print("❌ False:", False)
# Out:
# ✅ True: True
# ❌ False: False

# %% [markdown]
# ### 📊 Boolean Veri Tipi

# %%
# 📊 Boolean değişken oluşturma
myBoolean = True
print("Değer:", myBoolean)
print("Tip:", type(myBoolean))
# Out:
# Değer: True
# Tip: <class 'bool'>

# %%
# ❌ False değeri
myBoolean = False
print("Değer:", myBoolean)
print("Tip:", type(myBoolean))
# Out:
# Değer: False
# Tip: <class 'bool'>

# %% [markdown]
# <div style="background-color: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; border-radius: 5px; margin: 15px 0;">
#     <strong>💡 Önemli:</strong> Boolean değerleri <strong>büyük harfle</strong> başlar: <code>True</code> ve <code>False</code>
# </div>

# %% [markdown]
# ---
#
# ## 🔢 Karşılaştırma Operatörleri
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">⚖️ Karşılaştırma İşlemleri</h3>
#     <p style="font-size: 15px;">Karşılaştırma operatörleri <strong>her zaman Boolean</strong> döndürür! True veya False 🎯</p>
# </div>

# %% [markdown]
# ### ➕ Büyüktür (>)

# %%
# ➕ 5, 3'ten büyük mü?
result = 5 > 3
print("5 > 3 =", result)
print("Tip:", type(result))
# Out:
# 5 > 3 = True
# Tip: <class 'bool'>

# %% [markdown]
# ### ➖ Küçüktür (<)

# %%
# ➖ 3, 5'ten büyük mü?
result = 3 > 5
print("3 > 5 =", result)
# Out:
# 3 > 5 = False

# %%
# 🔍 2, 1'den küçük mü?
result = 2 < 1
print("2 < 1 =", result)
# Out:
# 2 < 1 = False

# %% [markdown]
# ### 📊 Karşılaştırma Operatörleri Tablosu
#
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 20px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <table style="width: 100%; border-collapse: collapse;">
#         <tr style="border-bottom: 2px solid #004d40;">
#             <th style="padding: 10px; text-align: left;">Operatör</th>
#             <th style="padding: 10px; text-align: left;">Açıklama</th>
#             <th style="padding: 10px; text-align: left;">Örnek</th>
#             <th style="padding: 10px; text-align: left;">Sonuç</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>></strong></td>
#             <td style="padding: 10px;">Büyüktür</td>
#             <td style="padding: 10px;">5 > 3</td>
#             <td style="padding: 10px;">✅ True</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong><</strong></td>
#             <td style="padding: 10px;">Küçüktür</td>
#             <td style="padding: 10px;">2 < 1</td>
#             <td style="padding: 10px;">❌ False</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>>=</strong></td>
#             <td style="padding: 10px;">Büyük veya eşit</td>
#             <td style="padding: 10px;">5 >= 5</td>
#             <td style="padding: 10px;">✅ True</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong><=</strong></td>
#             <td style="padding: 10px;">Küçük veya eşit</td>
#             <td style="padding: 10px;">3 <= 2</td>
#             <td style="padding: 10px;">❌ False</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>==</strong></td>
#             <td style="padding: 10px;">Eşit mi?</td>
#             <td style="padding: 10px;">5 == 5</td>
#             <td style="padding: 10px;">✅ True</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>!=</strong></td>
#             <td style="padding: 10px;">Eşit değil mi?</td>
#             <td style="padding: 10px;">5 != 3</td>
#             <td style="padding: 10px;">✅ True</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ---
#
# ## 🎯 Gerçek Hayat Örneği: Yaş Kontrolü
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <h3 style="color: white; margin-top: 0;">📊 Senaryo: Reşit Olma Kontrolü</h3>
#     <p style="font-size: 15px;">Kullanıcının yaşını alıp 18'den büyük olup olmadığını kontrol edelim! 🎂</p>
# </div>

# %% [markdown]
# ### 🎤 input() Fonksiyonu
#
# `input()` kullanıcıdan veri almamızı sağlar:

# %%
# 🎤 Kullanıcıdan yaş bilgisi al
# Not: Jupyter'de çalıştırırken input kutusuna değer girmeniz gerekecek
age = input("Yaşınızı girin: ")

print("📝 Girilen değer:", age)
print("📊 Veri tipi:", type(age))
# Out:
# 📝 Girilen değer: 30
# 📊 Veri tipi: <class 'str'>

# %% [markdown]
# <div style="background-color: #fff3cd; padding: 15px; border-left: 5px solid #ffc107; border-radius: 5px; margin: 15px 0;">
#     <strong>⚠️ Dikkat:</strong> <code>input()</code> fonksiyonu <strong>her zaman string</strong> döndürür! Sayısal işlem için <code>int()</code> ile dönüştürmeliyiz.
# </div>

# %% [markdown]
# ### ✅ Yaş Kontrolü - Boolean Kullanımı

# %%
# 🔄 String'i integer'a çevir ve kontrol et
age = "25"  # Örnek değer (input'tan geldiğini varsayalım)
age_int = int(age)

# ✅ Reşit mi kontrolü
is_adult = age_int > 18

print(f"🎂 Yaş: {age_int}")
print(f"✅ Reşit mi? {is_adult}")
print(f"📊 Boolean tipi: {type(is_adult)}")
# Out:
# 🎂 Yaş: 25
# ✅ Reşit mi? True
# 📊 Boolean tipi: <class 'bool'>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 20px; border-radius: 10px; color: #5d4037; margin: 20px 0; box-shadow: 0 5px 15px rgba(0,0,0,0.1);">
#     <h3 style="margin-top: 0;">🎯 İşlem Adımları</h3>
#     <ol style="font-size: 14px;">
#         <li>📝 <code>input()</code> ile kullanıcıdan string alındı: <code>"25"</code></li>
#         <li>🔄 <code>int()</code> ile integer'a çevrildi: <code>25</code></li>
#         <li>⚖️ Karşılaştırma yapıldı: <code>25 > 18</code></li>
#         <li>✅ Boolean döndü: <code>True</code></li>
#     </ol>
# </div>

# %% [markdown]
# ## 📝 Flashcard #7: Boolean
#
# <div style="background-color: #fff9c4; padding: 20px; border-radius: 10px; border: 3px dashed #f57f17; margin: 20px 0;">
#
# **🎯 Sorular ve Cevaplar:**
#
# ---
#
# **Q1:** Boolean kaç farklı değer alabilir?
# **A1:** **2 değer:** True veya False ✅❌
#
# ---
#
# **Q2:** Boolean veri tipinin İngilizce adı nedir?
# **A2:** `bool` 📊
#
# ---
#
# **Q3:** Karşılaştırma operatörleri ne döndürür?
# **A3:** **Her zaman Boolean** döndürür (True veya False) ⚖️
#
# ---
#
# **Q4:** `5 > 3` işleminin sonucu nedir?
# **A4:** `True` ✅
#
# ---
#
# **Q5:** `input()` fonksiyonu hangi veri tipinde değer döndürür?
# **A5:** **String** (str) - Sayıya çevirmek için `int()` kullanılır 🔄
#
# ---
#
# **Q6:** `==` ve `=` arasındaki fark nedir?
# **A6:** `=` atama, `==` karşılaştırma operatörüdür ⚠️
#
# ---
#
# **Q7:** Boolean'lar nerede kullanılır?
# **A7:** if-else koşulları, while döngüleri, filtreleme işlemleri 🎯
#
# </div>

# %% [markdown]
# ---
# ---
#
# # 🎓 KAPANIŞ VE ÖZET
# ## 🏆 Day 4'ü Tamamladınız!
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; margin: 30px 0; box-shadow: 0 10px 30px rgba(0,0,0,0.3);">
#     <h2 style="color: white; margin-top: 0; text-align: center;">🎉 TEBRİKLER! 🎉</h2>
#     <p style="font-size: 18px; text-align: center; margin: 20px 0;">Python'un en önemli <strong>4 veri yapısını</strong> öğrendiniz!</p>
# </div>

# %% [markdown]
# ## 📚 Bugün Öğrendiklerimiz
#
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 25px; border-radius: 10px; color: #4a0e0e; margin: 20px 0;">
#
# ### 1️⃣ 📖 DICTIONARY (Sözlük)
# - ✅ Key-value pairing konsepti
# - ✅ Hızlı erişim (hash table)
# - ✅ keys(), values(), get() metodları
# - ✅ Nested dictionary yapıları
# - ✅ JSON veriler için ideal
#
# ---
#
# ### 2️⃣ 🎨 SET (Küme)
# - ✅ Benzersiz elemanlar (unique)
# - ✅ Sırasız yapı
# - ✅ union() - Birleşim işlemi
# - ✅ intersection() - Kesişim işlemi
# - ✅ Tekrar temizleme
#
# ---
#
# ### 3️⃣ 🔒 TUPLE (Demet)
# - ✅ Immutable (değiştirilemez)
# - ✅ List'ten daha hızlı
# - ✅ index() ve count() metodları
# - ✅ Dictionary key olarak kullanılabilir
# - ✅ Güvenli veri saklama
#
# ---
#
# ### 4️⃣ ✅ BOOLEAN (Mantıksal)
# - ✅ True/False değerleri
# - ✅ Karşılaştırma operatörleri
# - ✅ if-else için temel
# - ✅ input() ile kullanım
#
# </div>

# %% [markdown]
# ## 🗺️ Veri Yapıları Karar Ağacı
#
# <div style="background: linear-gradient(135deg, #84fab0 0%, #8fd3f4 100%); padding: 25px; border-radius: 10px; color: #004d40; margin: 20px 0; box-shadow: 0 8px 20px rgba(0,0,0,0.2);">
#
# ### 🤔 Hangi Veri Yapısını Kullanmalıyım?
#
# **📋 LIST kullan:**
# - Sıralı veriler gerekiyorsa
# - Elemanları değiştireceksen
# - Tekrarlı elemanlar olabilirse
#
# **📖 DICTIONARY kullan:**
# - Key-value ilişkisi gerekiyorsa
# - Hızlı erişim önemliyse
# - JSON formatında verilerle çalışıyorsan
#
# **🎨 SET kullan:**
# - Benzersiz elemanlar istiyorsan
# - Tekrarları temizlemek gerekiyorsa
# - Matematiksel küme işlemleri yapacaksan
#
# **🔒 TUPLE kullan:**
# - Veriler değişmemeli
# - Performans kritikse
# - Dictionary key'i olarak kullanacaksan
#
# </div>

# %% [markdown]
# ## 📊 Final Karşılaştırma Tablosu
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; margin: 20px 0;">
#     <table style="width: 100%; border-collapse: collapse; color: white;">
#         <tr style="border-bottom: 2px solid white;">
#             <th style="padding: 10px;">Özellik</th>
#             <th style="padding: 10px;">📋 List</th>
#             <th style="padding: 10px;">📖 Dict</th>
#             <th style="padding: 10px;">🎨 Set</th>
#             <th style="padding: 10px;">🔒 Tuple</th>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Sıralı</strong></td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">❌</td>
#             <td style="padding: 10px;">❌</td>
#             <td style="padding: 10px;">✅</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Değiştirilebilir</strong></td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">❌</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Tekrar</strong></td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">❌ (key)</td>
#             <td style="padding: 10px;">❌</td>
#             <td style="padding: 10px;">✅</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Index</strong></td>
#             <td style="padding: 10px;">✅</td>
#             <td style="padding: 10px;">❌</td>
#             <td style="padding: 10px;">❌</td>
#             <td style="padding: 10px;">✅</td>
#         </tr>
#         <tr>
#             <td style="padding: 10px;"><strong>Syntax</strong></td>
#             <td style="padding: 10px;">[]</td>
#             <td style="padding: 10px;">{k:v}</td>
#             <td style="padding: 10px;">{}</td>
#             <td style="padding: 10px;">()</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 40px; border-radius: 15px; color: white; margin: 30px 0; text-align: center; box-shadow: 0 10px 30px rgba(0,0,0,0.3);">
#     <h1 style="color: white; margin: 0; font-size: 48px;">🎉</h1>
#     <h2 style="color: white; margin: 10px 0;">DAY 4 TAMAMLANDI!</h2>
#     <h1 style="color: white; margin: 0; font-size: 48px;">🏆</h1>
#     <p style="font-size: 20px; margin: 20px 0;">Sen harikasın! Öğrenmeye devam et! 💪</p>
#     <p style="font-size: 16px; margin: 10px 0;">From Zero to Hero 🚀</p>
# </div>
#
# ---
#
# <div style="text-align: center; padding: 20px; color: #666;">
#     <p style="font-size: 14px;">📝 <strong>Veri Bilimi ve Makine Öğrenmesi 2026 - 100 Günlük Bootcamp</strong></p>
#     <p style="font-size: 12px;">Created with ❤️ by Cemal YÜKSEL</p>
#     <p style="font-size: 12px;">2 Ocak 2026</p>
# </div>
