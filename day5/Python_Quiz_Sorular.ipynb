# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(240, 147, 251, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 1: String İndeksleme</h2>
#     <p style='color: #ffe0f0; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki string'in 5. harfini bir değişkene atayınız</p>
# </div>

# %%
# SORU 1: Aşağıdaki string'in 5. harfini bir değişkene atayınız
my_string = "Python Ogreniyorum"

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(79, 172, 254, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 2: String Slicing</h2>
#     <p style='color: #e0f7ff; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki string'in 5. ve 8. karakteri arasındaki tüm harflerini yazdırınız (5 ve 8 dahil)</p>
# </div>

# %%
# SORU 2: Aşağıdaki string'in 5. ve 8. karakteri arasındaki tüm harflerini yazdırınız (5 ve 8 dahil)
my_new_string = "ProgramlamayaMerhabaDedik"

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(250, 112, 154, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 3: String Tersine Çevirme</h2>
#     <p style='color: #fff5e0; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki string'i kod ile tersten yazın</p>
# </div>

# %%
# SORU 3: Aşağıdaki string'i kod ile tersten yazın
my_last_string = "Afyonkarahisarlilastiramadiklarimizdanmisiniz"

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #30cfd0 0%, #330867 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(48, 207, 208, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 4: Veri Tipi Belirleme</h2>
#     <p style='color: #d0f0ff; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki işlemin sonucu hangi veri tipinde olacaktır?</p>
# </div>

# %%
# SORU 4: Aşağıdaki işlemin sonucu hangi veri tipinde olacaktır?
4 + 12.2 + 48

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #ff9a56 0%, #ff6a88 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(255, 154, 86, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 5: İşlem Önceliği</h2>
#     <p style='color: #fff0e6; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki işlemin sonucu kaçtır?</p>
# </div>

# %%
# SORU 5: Aşağıdaki işlemin sonucu kaçtır?
5 + 7 * 12

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(168, 237, 234, 0.3);'>
#     <h2 style='color: #2c5f5d; margin: 0;'>📌 Soru 6: Liste Oluşturma</h2>
#     <p style='color: #4a7c7a; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Bu listeyi en az 2 farklı yoldan oluşturunuz: [1, 3, "a"]</p>
# </div>

# %%
# SORU 6: Bu listeyi en az 2 farklı yoldan oluşturunuz: [1, 3, "a"]

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(102, 126, 234, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 7: Nested List Erişimi</h2>
#     <p style='color: #e6e0ff; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki "b"'yi tek satırda alınız</p>
# </div>

# %%
# SORU 7: Aşağıdaki "b"'yi tek satırda alınız
my_list = [3.14, 4, [2, 3, "b"], True]

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(240, 147, 251, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 8: Dictionary Erişimi</h2>
#     <p style='color: #ffe0f0; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki "a"'yı tek satırda alınız</p>
# </div>

# %%
# SORU 8: Aşağıdaki "a"'yı tek satırda alınız
my_dictionary = {"key1": 20.25, "kk2": [40, {"k21": "a"}]}

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(79, 172, 254, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 9: Set Dönüşümü</h2>
#     <p style='color: #e0f7ff; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki liste set'e çevrilince hangi değerler içinde kalacaktır?</p>
# </div>

# %%
# SORU 9: Aşağıdaki liste set'e çevrilince hangi değerler içinde kalacaktır?
my_list_to_be_set = [3, 4, 9, 3, 21, 22, 4, 3, 9, 10, 21, 22]

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 25px; border-radius: 15px; margin: 20px 0; box-shadow: 0 6px 20px rgba(250, 112, 154, 0.3);'>
#     <h2 style='color: white; margin: 0;'>📌 Soru 10: Boolean Karşılaştırma</h2>
#     <p style='color: #fff5e0; font-size: 16px; margin-top: 10px; margin-bottom: 0;'>Aşağıdaki ifadenin sonucu ne olacaktır?</p>
# </div>

# %%
# SORU 10: Aşağıdaki ifadenin sonucu ne olacaktır?
x = 30 * 5 + 3
y = 108 - 2 * 4
x > y

#cevap



#cevap

# %% [markdown]
# ---
# <div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 50px; border-radius: 25px; margin-top: 40px; box-shadow: 0 10px 40px rgba(102, 126, 234, 0.5);'>
#     <h2 style='color: white; text-align: center; font-size: 36px; margin: 0;'>🎉 Quiz Tamamlandı!</h2>
#     <p style='color: #f0e7ff; text-align: center; font-size: 18px; margin-top: 20px; line-height: 1.8;'>
#         Tüm soruları çözdüyseniz, kendinizi tebrik edebilirsiniz! <br>
#         Çözümlerinizi kontrol etmek için <code>Python_Quiz_Cevaplari.ipynb</code> dosyasına bakabilirsiniz.
#     </p>
# </div>
#
# <div style='background: linear-gradient(135deg, #ffecd2 0%, #fcb69f 100%); padding: 30px; border-radius: 20px; margin-top: 25px; box-shadow: 0 8px 30px rgba(252, 182, 159, 0.3);'>
#     <h3 style='color: #8b4513; margin-top: 0;'>💡 Öneriler</h3>
#     <ul style='color: #654321; font-size: 16px; line-height: 2;'>
#         <li>📚 Anlamadığınız sorular için Python dokümantasyonunu inceleyin</li>
#         <li>🧪 Farklı senaryolar deneyerek öğrenmenizi pekiştirin</li>
#         <li>💬 Yorum satırları ekleyerek düşünce sürecinizi belgeleyin</li>
#         <li>🔄 Quiz'i düzenli aralıklarla tekrar çözerek pratik yapın</li>
#         <li>🤝 Çözümlerinizi başkalarıyla paylaşıp tartışın</li>
#     </ul>
# </div>
#
# <div style='background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 30px; border-radius: 20px; margin-top: 25px; text-align: center; box-shadow: 0 8px 30px rgba(240, 147, 251, 0.4);'>
#     <h3 style='color: white; margin: 0; font-size: 24px;'>💪 Başarılar!</h3>
#     <p style='color: #ffe0f0; font-size: 16px; margin-top: 15px;'>
#         <i>"Kodlama becerisi, sabır ve pratik ile gelişir!"</i>
#     </p>
#     <p style='color: white; font-size: 20px; margin-top: 20px; margin-bottom: 0;'>🎓 Happy Coding! 🐍</p>
# </div>
